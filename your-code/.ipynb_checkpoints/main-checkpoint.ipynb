# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# %matplotlib inline
# import numpy and pandas
import pandas as pd
import numpy as np
import re

# %% [markdown]
# # Challenge 1 - Analysis of Variance
#
# In this part of the lesson, we will perform an analysis of variance to determine whether the factors in our model create a significant difference in the group means. We will be examining a dataset of FIFA players. We'll start by loading the data using the code in the cell below.

# %%
# Run this code:
fifa = pd.read_csv('fifa.csv')

# %% [markdown]
# Let's examine the dataset by looking at the `head`.

# %%
# Your code here:
fifa.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
#
#                   Club    Value Preferred Foot Position  Weak Foot  \
# 0         FC Barcelona  €110.5M           Left       RF        4.0
# 1             Juventus     €77M          Right       ST        4.0
# 2  Paris Saint-Germain  €118.5M          Right       LW        5.0
# 3    Manchester United     €72M          Right       GK        3.0
# 4      Manchester City    €102M          Right      RCM        5.0
#
#    Acceleration  SprintSpeed  Stamina  Strength  LongShots  Aggression  \
# 0          91.0         86.0     72.0      59.0       94.0        48.0
# ...

# %%
fifa.columns
# Out:
# Index(['Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club', 'Value',
#        'Preferred Foot', 'Position', 'Weak Foot', 'Acceleration',
#        'SprintSpeed', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties'],
#       dtype='object')

# %%
fifa.dtypes
# Out:
# Name               object
# Age                 int64
# Nationality        object
# Overall             int64
# Potential           int64
# Club               object
# Value              object
# Preferred Foot     object
# Position           object
# Weak Foot         float64
# Acceleration      float64
# SprintSpeed       float64
# Stamina           float64
# Strength          float64
# LongShots         float64
# Aggression        float64
# Interceptions     float64
# Positioning       float64
# Vision            float64
# Penalties         float64
# dtype: object

# %%
fifa.isna().sum()
# Out:
# Name                0
# Age                 0
# Nationality         0
# Overall             0
# Potential           0
# Club              241
# Value               0
# Preferred Foot     48
# Position           60
# Weak Foot          48
# Acceleration       48
# SprintSpeed        48
# Stamina            48
# Strength           48
# LongShots          48
# Aggression         48
# Interceptions      48
# Positioning        48
# Vision             48
# Penalties          48
# dtype: int64

# %%
fifa.count()
# Out:
# Name              18207
# Age               18207
# Nationality       18207
# Overall           18207
# Potential         18207
# Club              17966
# Value             18207
# Preferred Foot    18159
# Position          18147
# Weak Foot         18159
# Acceleration      18159
# SprintSpeed       18159
# Stamina           18159
# Strength          18159
# LongShots         18159
# Aggression        18159
# Interceptions     18159
# Positioning       18159
# Vision            18159
# Penalties         18159
# dtype: int64

# %% [markdown]
# Player's values are expressed in millions of euros. We would like this column to be numeric. Therefore, let's create a numeric value column. Do this by stripping all non-numeric characters from each cell. Assign this new data to `ValueNumeric`. There is no need to multiply the value to be expressed in millions.

# %%
# Your code here:
fifa['numero'] = fifa['Value'].apply(lambda value : float(re.findall(r'(?<=€)\d+\.*\d*', value)[0]))
fifa['ValueMult'] = fifa['Value'].apply(lambda value :(re.findall(r'(M|K)*$', value)[0]))

# %%
#fifa['Value']
fifa.loc[fifa.ValueMult=='M','multiplicador'] = 1000000
fifa.loc[fifa.ValueMult=='K','multiplicador'] = 1000

# %%
fifa['ValueNumeric'] = fifa.ValueNum * fifa.multiplicador

# %%
fifa.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
#
#                   Club    Value Preferred Foot Position  Weak Foot  ...  \
# 0         FC Barcelona  €110.5M           Left       RF        4.0  ...
# 1             Juventus     €77M          Right       ST        4.0  ...
# 2  Paris Saint-Germain  €118.5M          Right       LW        5.0  ...
# 3    Manchester United     €72M          Right       GK        3.0  ...
# 4      Manchester City    €102M          Right      RCM        5.0  ...
#
#    LongShots  Aggression  Interceptions  Positioning  Vision  Penalties  \
# 0       94.0        48.0           22.0         94.0    94.0       75.0
# ...

# %%
fifa.dtypes
# Out:
# Name               object
# Age                 int64
# Nationality        object
# Overall             int64
# Potential           int64
# Club               object
# Value              object
# Preferred Foot     object
# Position           object
# Weak Foot         float64
# Acceleration      float64
# SprintSpeed       float64
# Stamina           float64
# Strength          float64
# LongShots         float64
# Aggression        float64
# Interceptions     float64
# Positioning       float64
# Vision            float64
# Penalties         float64
# ValueNumeric      float64
# ValueMult          object
# ValueNum          float64
# multiplicador     float64
# dtype: object

# %% [markdown]
# #### We'd like to determine whether a player's preffered foot and position have an impact on their value.
#
# Using the `statsmodels` library, we are able to produce an ANOVA table without munging our data. Create an ANOVA table with value as a function of position and preferred foot. Recall that pivoting is performed by the `C` function.
#
# Hint: For columns that have a space in their name, it is best to refer to the column using the dataframe (For example: for column `A`, we will use `df['A']`).

# %%
# Your code here:
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
model = ols('ValueNumeric ~ C(fifa["Position"])+C(fifa["Preferred Foot"])', data = fifa).fit()

# %%
import seaborn as sns

# %%
anova_table = sm.stats.anova_lm(model, typ = 2)
anova_table
# Out:
#                                  sum_sq       df          F        PR(>F)
# C(fifa["Position"])        1.659610e+16     26.0  20.694853  1.699733e-95
# C(fifa["Preferred Foot"])  2.316461e+14      1.0   7.510257  6.140953e-03
# Residual                   5.514593e+17  17879.0        NaN           NaN

# %% [markdown]
# What is your conclusion from this ANOVA?

# %%
# Your conclusions here:
# sum_sq = suma de cuadrados en terminos del modelo
# df = Grados de libertad en terminos del modelo
# F = Valor F estadistico para la importancia de agregar términos modelo
# PR(>F) = P value para la significancia
# alguna de las posiciones tiene una diferencia significativa respecto a 
# las otras posiciones o en el valuenumeric
# mientras que prefered foot, tiene una diferencia menor respecto a valuenumeric
#sin embargo por los grados de libertad, no se puede distinguir si es con un pie u otro
# o si el valuenumeric, se relaciona por el pie
# resumiendo en que existe mucha varianza entre las variables utilizadas

# %% [markdown]
# After looking at a model of both preffered foot and position, we decide to create an ANOVA table for nationality. Create an ANOVA table for numeric value as a function of nationality.

# %%
# Your code here:
model2 = ols('ValueNumeric ~ C(fifa["Nationality"])', data = fifa).fit()
anova_table2 = sm.stats.anova_lm(model2, typ = 2)
anova_table2
# Out:
# c:\program files\python37\lib\site-packages\statsmodels\base\model.py:1752: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 163, but rank is 162
#   'rank is %d' % (J, J_), ValueWarning)
#                               sum_sq       df         F         PR(>F)
# C(fifa["Nationality"])  3.303532e+16    163.0  6.732612  2.370904e-132
# Residual                5.355897e+17  17792.0       NaN            NaN

# %% [markdown]
# What is your conclusion from this ANOVA?

# %%
# El valor de la nacionalidad y el valuenumeric, nos dan una varianza significativa

# %% [markdown]
# # Challenge 2 - Linear Regression
#
# Our goal with using linear regression is to create a mathematical model that will enable us to predict the outcome of one variable using one or more additional independent variables.
#
# We'll start by ensuring there are no missing values. Examine all variables for all missing values. If there are missing values in a row, remove the entire row.

# %%
# Your code here:
fifa = fifa.dropna()

# %%
fifa.isnull().sum()
# Out:
# Name              0
# Age               0
# Nationality       0
# Overall           0
# Potential         0
# Club              0
# Value             0
# Preferred Foot    0
# Position          0
# Weak Foot         0
# Acceleration      0
# SprintSpeed       0
# Stamina           0
# Strength          0
# LongShots         0
# Aggression        0
# Interceptions     0
# Positioning       0
# Vision            0
# Penalties         0
# ValueNumeric      0
# ValueMult         0
# ValueNum          0
# multiplicador     0
# dtype: int64

# %% [markdown]
# Using the FIFA dataset, in the cell below, create a linear model predicting value using stamina and sprint speed. create the model using `statsmodels`. Print the model summary.
#
# Hint: remember to add an intercept to the model using the `add_constant` function.

# %%
# Your code here:
model3 = ols('ValueNumeric ~ C(fifa["Stamina"]) + C(fifa["SprintSpeed"])' , data = fifa).fit()
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           ValueNumeric   R-squared:                       0.121
# Model:                            OLS   Adj. R-squared:                  0.113
# Method:                 Least Squares   F-statistic:                     14.54
# Date:                Thu, 01 Aug 2019   Prob (F-statistic):               0.00
# Time:                        13:25:51   Log-Likelihood:            -3.0260e+05
# No. Observations:               17907   AIC:                         6.055e+05
# Df Residuals:                   17738   BIC:                         6.069e+05
# Df Model:                         168
# Covariance Type:            nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Report your findings from the model summary. In particular, report about the model as a whole using the F-test and how much variation is predicted by the model using the r squared.

# %%
# Your conclusions here:
#Conforme a la R cuadrada, encontramos que el valor entre ambas variables es solo del 12%, lo cual nos indica que existe muy poca relacion

# %% [markdown]
# Next, create a second regression model predicting value using potential. Create the model using `statsmodels` and print the model summary. Remember to add a constant term.

# %%
# Your code here:
model4 = ols('ValueNumeric ~ C(fifa["Potential"])' , data = fifa).fit()
model4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           ValueNumeric   R-squared:                       0.705
# Model:                            OLS   Adj. R-squared:                  0.704
# Method:                 Least Squares   F-statistic:                     928.2
# Date:                Thu, 01 Aug 2019   Prob (F-statistic):               0.00
# Time:                        13:17:37   Log-Likelihood:            -2.9283e+05
# No. Observations:               17907   AIC:                         5.857e+05
# Df Residuals:                   17860   BIC:                         5.861e+05
# Df Model:                          46
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Report your findings from the model summary. In particular, report about the model as a whole using the F-test and how much variation is predicted by the model using the r squared.

# %%
# Your conclusions here:
# El valor de r-squared es muy alto, con lo cual podemos decir que si hay una relacion entre las variables utilizadas y con eso podriamos dar una conclusion mas acertada

# %% [markdown]
# Plot a scatter plot of value vs. potential. Do you see a linear relationship?

# %%
# Your code here:
sns.scatterplot(fifa['Potential'], fifa["ValueNumeric"])

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           ValueNumeric   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                  0.028
# Method:                 Least Squares   F-statistic:                     20.12
# Date:                Thu, 01 Aug 2019   Prob (F-statistic):           7.41e-96
# Time:                        13:23:41   Log-Likelihood:            -3.0349e+05
# No. Observations:               17907   AIC:                         6.070e+05
# Df Residuals:                   17879   BIC:                         6.073e+05
# Df Model:                          27
# Covariance Type:            nonrobust
# ...
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# ...
