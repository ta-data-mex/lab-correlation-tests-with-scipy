# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# %matplotlib inline
# import numpy and pandas
import numpy as np
import pandas as pd

# %% [markdown]
# # Challenge 1 - Analysis of Variance
#
# In this part of the lesson, we will perform an analysis of variance to determine whether the factors in our model create a significant difference in the group means. We will be examining a dataset of FIFA players. We'll start by loading the data using the code in the cell below.

# %%
# Run this code:
fifa = pd.read_csv('fifa.csv')

# %%
fifa.describe()
# Out:
#                 Age       Overall     Potential     Weak Foot  Acceleration  \
# count  18207.000000  18207.000000  18207.000000  18159.000000  18159.000000
# mean      25.122206     66.238699     71.307299      2.947299     64.614076
# std        4.669943      6.908930      6.136496      0.660456     14.927780
# min       16.000000     46.000000     48.000000      1.000000     12.000000
# 25%       21.000000     62.000000     67.000000      3.000000     57.000000
# 50%       25.000000     66.000000     71.000000      3.000000     67.000000
# 75%       28.000000     71.000000     75.000000      3.000000     75.000000
# max       45.000000     94.000000     95.000000      5.000000     97.000000
#
#         SprintSpeed       Stamina      Strength     LongShots    Aggression  \
# count  18159.000000  18159.000000  18159.000000  18159.000000  18159.000000
# mean      64.726967     63.219946     65.311967     47.109973     55.868991
# std       14.649953     15.894741     12.557000     19.260524     17.367967
# min       12.000000     12.000000     17.000000      3.000000     11.000000
# 25%       57.000000     56.000000     58.000000     33.000000     44.000000
# 50%       67.000000     66.000000     67.000000     51.000000     59.000000
# 75%       75.000000     74.000000     74.000000     62.000000     69.000000
# max       96.000000     96.000000     97.000000     94.000000     95.000000
#
#        Interceptions   Positioning        Vision     Penalties
# count   18159.000000  18159.000000  18159.000000  18159.000000
# mean       46.698276     49.958478     53.400903     48.548598
# std        20.696909     19.529036     14.146881     15.704053
# min         3.000000      2.000000     10.000000      5.000000
# 25%        26.000000     38.000000     44.000000     39.000000
# 50%        52.000000     55.000000     55.000000     49.000000
# 75%        64.000000     64.000000     64.000000     60.000000
# max        92.000000     95.000000     94.000000     92.000000

# %% [markdown]
# Let's examine the dataset by looking at the `head`.

# %%
# Your code here:
fifa.head(2)
# Out:
#                 Name  Age Nationality  Overall  Potential          Club  \
# 0           L. Messi   31   Argentina       94         94  FC Barcelona
# 1  Cristiano Ronaldo   33    Portugal       94         94      Juventus
#
#      Value Preferred Foot Position  Weak Foot  Acceleration  SprintSpeed  \
# 0  €110.5M           Left       RF        4.0          91.0         86.0
# 1     €77M          Right       ST        4.0          89.0         91.0
#
#    Stamina  Strength  LongShots  Aggression  Interceptions  Positioning  \
# 0     72.0      59.0       94.0        48.0           22.0         94.0
# 1     88.0      79.0       93.0        63.0           29.0         95.0
#
#    Vision  Penalties
# 0    94.0       75.0
# 1    82.0       85.0

# %% [markdown]
# Player's values are expressed in millions of euros. We would like this column to be numeric. Therefore, let's create a numeric value column. Do this by stripping all non-numeric characters from each cell. Assign this new data to `ValueNumeric`. There is no need to multiply the value to be expressed in millions.

# %%
#Idea de Ramiro ##No correr
# fifa2 = fifa
# fifa2["ValueNumeric"] = fifa2["Value"].str.replace("€", "").str.replace("M","").str.replace("K","").astype(float)
# fifa2.head(3)

# %%
import re

# %%
#Nuestra idea
f = lambda x : re.sub(r'(€|M|K)','',str(x)) #esto esta mal porque ahora se confunden los miles y los millones
fifa['ValueNumeric'] = fifa['Value'].apply(f) #apply aplica la función f a todo lo de la columna 'Value'
fifa.ValueNumeric = pd.to_numeric(fifa.ValueNumeric) #Cambiar a float el valor de los jugadores
fifa.head(3)
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
#
#                   Club    Value Preferred Foot Position  Weak Foot  ...  \
# 0         FC Barcelona  €110.5M           Left       RF        4.0  ...
# 1             Juventus     €77M          Right       ST        4.0  ...
# 2  Paris Saint-Germain  €118.5M          Right       LW        5.0  ...
#
#    SprintSpeed  Stamina  Strength  LongShots  Aggression  Interceptions  \
# 0         86.0     72.0      59.0       94.0        48.0           22.0
# 1         91.0     88.0      79.0       93.0        63.0           29.0
# 2         90.0     81.0      49.0       82.0        56.0           36.0
#
#    Positioning  Vision  Penalties  ValueNumeric
# 0         94.0    94.0       75.0         110.5
# 1         95.0    82.0       85.0          77.0
# 2         89.0    87.0       81.0         118.5
#
# [3 rows x 21 columns]

# %%
#verificamos el tipo de variables
fifa.dtypes
# Out:
# Name               object
# Age                 int64
# Nationality        object
# Overall             int64
# Potential           int64
# Club               object
# Value              object
# Preferred Foot     object
# Position           object
# Weak Foot         float64
# Acceleration      float64
# SprintSpeed       float64
# Stamina           float64
# Strength          float64
# LongShots         float64
# Aggression        float64
# Interceptions     float64
# Positioning       float64
# Vision            float64
# Penalties         float64
# ValueNumeric      float64
# dtype: object

# %%
def g(x):
    if

# %%
fifa[fifa.Value.str.contains('K')]
# Out:
#                        Name  Age          Nationality  Overall  Potential  \
# 926                   Gomes   37               Brazil       77         77
# 1294            A. Bizzarri   40            Argentina       76         76
# 1625              D. Bonera   37                Italy       75         75
# 1668                 Rafael   36               Brazil       75         75
# 1720                Iraizoz   37                Spain       75         75
# 1788               A. Pérez   37             Colombia       75         75
# 1789               B. Jones   36            Australia       75         75
# 1792            A. McGregor   36             Scotland       75         75
# 1848                 Cássio   37               Brazil       75         75
# 1863             E. Moretti   37                Italy       75         75
# 1952             P. Guiñazú   39            Argentina       75         75
# 1960              C. Maggio   36                Italy       75         75
# 2062              J. Corona   37               Mexico       75         75
# 2085             M. Pasqual   36                Italy       74         74
# 2095             V. Demirel   36               Turkey       74         74
# 2243               R. Fanni   36               France       74         74
# 2312               A. Boruc   38               Poland       74         74
# 2380           Bruno Saltor   37                Spain       74         74
# 2574          Ricardo Costa   37             Portugal       74         74
# 2619              J. Drobný   38       Czech Republic       73         73
# 2628               B. Cesar   35             Slovenia       73         73
# 2666          S. von Bergen   35          Switzerland       73         73
# 2706              Cifuentes   39                Spain       73         73
# 2817            J. Gandolfi   37            Argentina       73         73
# 2821             S. Bertoli   40            Argentina       73         73
# 2834        M. Stekelenburg   35          Netherlands       73         73
# 2940                Bracali   37               Brazil       73         73
# 3043               Y. Ayhan   36               Turkey       73         73
# 3089           N. Penneteau   37               France       73         73
# 3096             J. Herrera   37                Chile       73         73
# ...                     ...  ...                  ...      ...        ...
# 18176            T. Hillman   17                Wales       48         57
# 18177             R. Roache   18  Republic of Ireland       48         69
# 18178          L. Wahlstedt   18               Sweden       48         65
# 18179           J. Williams   17              England       48         64
# 18180              M. Hurst   22             Scotland       48         58
# 18181              C. Maher   17  Republic of Ireland       48         66
# 18182               Y. Góez   18             Colombia       48         65
# 18184             D. Horton   18              England       48         55
# 18185              E. Tweed   19  Republic of Ireland       48         59
# 18186          Zhang Yufeng   20             China PR       47         64
# 18187             C. Ehlich   19              Germany       47         59
# 18188            L. Collins   17                Wales       47         62
# 18189            A. Kaltner   18              Germany       47         61
# 18190            L. Watkins   18              England       47         67
# 18191  J. Norville-Williams   18              England       47         65
# 18192             S. Squire   18              England       47         64
# 18193            N. Fuentes   18                Chile       47         64
# 18194              J. Milli   18                Italy       47         65
# 18195            S. Griffin   18  Republic of Ireland       47         67
# 18196           K. Fujikawa   19                Japan       47         61
# 18197            D. Holland   18  Republic of Ireland       47         61
# 18198            J. Livesey   18              England       47         70
# 18199          M. Baldisimo   18               Canada       47         69
# 18200              J. Young   18             Scotland       47         62
# 18201              D. Walsh   18  Republic of Ireland       47         68
# 18202          J. Lundstram   19              England       47         65
# 18203    N. Christoffersson   19               Sweden       47         63
# 18204             B. Worman   16              England       47         67
# 18205        D. Walker-Rice   17              England       47         66
# 18206             G. Nugent   16              England       46         66
#
#                          Club  Value Preferred Foot Position  Weak Foot  ...  \
# 926                   Watford  €600K          Right       GK        2.0  ...
# 1294                   Foggia  €525K          Right       GK        3.0  ...
# 1625            Villarreal CF  €900K          Right       CB        3.0  ...
# 1668                 Cagliari  €900K          Right       GK        3.0  ...
# 1720                Girona FC  €450K          Right       GK        3.0  ...
# 1788           Deportivo Cali  €900K          Right      RDM        3.0  ...
# 1789                 Al Nassr  €900K           Left       GK        2.0  ...
# 1792               Rangers FC  €900K          Right       GK        3.0  ...
# 1848               Al Taawoun  €450K          Right       GK        2.0  ...
# 1863                   Torino  €900K           Left      LCB        2.0  ...
# 1952   Club Atlético Talleres  €450K           Left      LCM        3.0  ...
# 1960                Benevento  €775K          Right       RB        2.0  ...
# 2062                Cruz Azul  €450K          Right       GK        3.0  ...
# 2085                   Empoli  €650K           Left       LB        2.0  ...
# 2095            Fenerbahçe SK  €750K          Right       GK        2.0  ...
# 2243          Montreal Impact  €750K          Right      RCB        3.0  ...
# 2312              Bournemouth  €375K          Right       GK        3.0  ...
# 2380   Brighton & Hove Albion  €650K          Right       RB        3.0  ...
# 2574               CD Tondela  €750K          Right      LCB        3.0  ...
# 2619         SV Werder Bremen  €270K          Right       GK        2.0  ...
# 2628            Chievo Verona  €950K           Left       CB        3.0  ...
# 2666           BSC Young Boys  €950K          Right      LCB        3.0  ...
# 2706                 Cádiz CF  €270K          Right       GK        3.0  ...
# 2817   Club Atlético Talleres  €550K          Right       CB        2.0  ...
# 2821                Patronato  €270K          Right       GK        2.0  ...
# 2834                  Everton  €950K          Right       GK        4.0  ...
# 2940              Boavista FC  €270K          Right       GK        3.0  ...
# 3043           MKE Ankaragücü  €550K          Right      RCB        2.0  ...
# 3089    Sporting de Charleroi  €270K           Left       GK        3.0  ...
# 3096     Universidad de Chile  €270K          Right       GK        3.0  ...
# ...                       ...    ...            ...      ...        ...  ...
# 18176          Newport County   €40K          Right       RM        2.0  ...
# 18177               Blackpool   €70K          Right       ST        3.0  ...
# 18178              Dalkurd FF   €50K          Right       GK        2.0  ...
# 18179        Northampton Town   €50K          Right       CB        3.0  ...
# 18180        St. Johnstone FC   €40K          Right       GK        2.0  ...
# 18181          Bray Wanderers   €50K          Right       RB        2.0  ...
# 18182       Atlético Nacional   €50K          Right      CDM        3.0  ...
# 18184            Lincoln City   €40K          Right       CM        3.0  ...
# 18185              Derry City   €50K          Right      LCM        3.0  ...
# 18186        Beijing Renhe FC   €60K          Right       CM        3.0  ...
# 18187      SpVgg Unterhaching   €40K          Right       RB        3.0  ...
# 18188          Newport County   €60K          Right       CM        3.0  ...
# 18189      SpVgg Unterhaching   €60K          Right       ST        3.0  ...
# 18190        Cambridge United   €60K          Right       CM        3.0  ...
# 18191        Cambridge United   €50K           Left       LB        3.0  ...
# 18192        Cambridge United   €50K          Right      CDM        3.0  ...
# 18193          Unión Española   €50K          Right       RB        2.0  ...
# 18194                   Lecce   €50K          Right       GK        3.0  ...
# 18195            Waterford FC   €60K          Right       CM        3.0  ...
# 18196            Júbilo Iwata   €60K          Right       CM        3.0  ...
# 18197               Cork City   €60K          Right       CM        3.0  ...
# 18198           Burton Albion   €60K          Right       GK        2.0  ...
# 18199  Vancouver Whitecaps FC   €70K          Right       CM        3.0  ...
# 18200            Swindon Town   €60K           Left       ST        2.0  ...
# 18201            Waterford FC   €60K           Left       RB        3.0  ...
# 18202         Crewe Alexandra   €60K          Right       CM        2.0  ...
# 18203          Trelleborgs FF   €60K          Right       ST        2.0  ...
# 18204        Cambridge United   €60K          Right       ST        3.0  ...
# 18205         Tranmere Rovers   €60K          Right       RW        3.0  ...
# 18206         Tranmere Rovers   €60K          Right       CM        3.0  ...
#
#        Stamina  Strength  LongShots  Aggression  Interceptions  Positioning  \
# 926       27.0      64.0       14.0        40.0           20.0         12.0
# 1294      31.0      55.0       19.0        40.0           19.0         10.0
# 1625      34.0      77.0       53.0        80.0           79.0         27.0
# 1668      41.0      49.0       14.0        31.0           10.0         12.0
# 1720      33.0      83.0       14.0        38.0           23.0         16.0
# 1788      66.0      74.0       74.0        88.0           81.0         69.0
# 1789      40.0      72.0       11.0        32.0           23.0         17.0
# 1792      30.0      71.0       14.0        53.0           18.0         13.0
# 1848      30.0      64.0       11.0        40.0           22.0         13.0
# 1863      39.0      68.0       39.0        74.0           84.0         31.0
# 1952      89.0      79.0       60.0        84.0           73.0         67.0
# 1960      79.0      77.0       69.0        72.0           67.0         74.0
# 2062      25.0      52.0       12.0        11.0           23.0         15.0
# 2085      68.0      66.0       62.0        66.0           72.0         66.0
# 2095      42.0      83.0       12.0        45.0           19.0         12.0
# 2243      65.0      79.0       58.0        71.0           76.0         53.0
# 2312      31.0      69.0       15.0        38.0           25.0         17.0
# 2380      55.0      66.0       46.0        74.0           80.0         58.0
# 2574      69.0      77.0       32.0        91.0           70.0         56.0
# 2619      23.0      66.0       15.0        26.0           14.0          8.0
# 2628      46.0      92.0       32.0        70.0           78.0         20.0
# 2666      73.0      77.0       32.0        77.0           74.0         31.0
# 2706      39.0      68.0       16.0        28.0           22.0         14.0
# 2817      67.0      81.0       40.0        82.0           71.0         26.0
# 2821      19.0      60.0       10.0        33.0           11.0          7.0
# 2834      30.0      77.0       11.0        41.0           26.0         12.0
# 2940      31.0      69.0       17.0        29.0           21.0         12.0
# 3043      66.0      78.0       25.0        86.0           76.0         21.0
# 3089      26.0      63.0       11.0        36.0           26.0         11.0
# 3096      28.0      59.0       12.0        44.0           15.0         14.0
# ...        ...       ...        ...         ...            ...          ...
# 18176     50.0      42.0       33.0        22.0           21.0         40.0
# 18177     51.0      44.0       41.0        25.0           13.0         48.0
# 18178     20.0      38.0        6.0        20.0           10.0          7.0
# 18179     55.0      54.0       20.0        47.0           47.0         28.0
# 18180     33.0      58.0       20.0        20.0           29.0         13.0
# 18181     60.0      48.0       33.0        53.0           46.0         43.0
# 18182     54.0      48.0       25.0        50.0           48.0         25.0
# 18184     59.0      66.0       31.0        53.0           49.0         35.0
# 18185     60.0      43.0       30.0        52.0           45.0         35.0
# 18186     46.0      60.0       34.0        55.0           43.0         29.0
# 18187     61.0      59.0       41.0        38.0           36.0         44.0
# 18188     33.0      40.0       36.0        36.0           36.0         44.0
# 18189     55.0      60.0       35.0        28.0           25.0         43.0
# 18190     61.0      55.0       34.0        44.0           44.0         51.0
# 18191     38.0      55.0       25.0        55.0           55.0         47.0
# 18192     55.0      59.0       36.0        55.0           44.0         38.0
# 18193     54.0      40.0       22.0        48.0           49.0         35.0
# 18194     15.0      59.0        5.0        17.0            5.0          3.0
# 18195     54.0      49.0       30.0        51.0           35.0         47.0
# 18196     35.0      51.0       30.0        55.0           44.0         28.0
# 18197     50.0      38.0       37.0        37.0           28.0         39.0
# 18198     20.0      38.0        5.0        25.0            6.0          5.0
# 18199     42.0      43.0       30.0        53.0           49.0         35.0
# 18200     31.0      31.0       51.0        26.0           16.0         46.0
# 18201     39.0      52.0       16.0        44.0           45.0         20.0
# 18202     40.0      47.0       38.0        46.0           46.0         39.0
# 18203     43.0      67.0       42.0        47.0           16.0         46.0
# 18204     55.0      32.0       45.0        32.0           15.0         48.0
# 18205     40.0      48.0       34.0        33.0           22.0         44.0
# 18206     47.0      60.0       32.0        56.0           42.0         34.0
#
#        Vision  Penalties  ValueNumeric  ValueMiles
# 926      59.0       41.0         600.0        €600
# 1294     49.0       20.0         525.0        €525
# 1625     41.0       49.0         900.0        €900
# 1668     45.0       22.0         900.0        €900
# 1720     53.0       13.0         450.0        €450
# 1788     72.0       62.0         900.0        €900
# 1789     30.0       35.0         900.0        €900
# 1792     60.0       23.0         900.0        €900
# 1848     60.0       24.0         450.0        €450
# 1863     31.0       49.0         900.0        €900
# 1952     69.0       55.0         450.0        €450
# 1960     58.0       57.0         775.0        €775
# 2062     40.0       21.0         450.0        €450
# 2085     70.0       50.0         650.0        €650
# 2095     50.0       11.0         750.0        €750
# 2243     58.0       57.0         750.0        €750
# 2312     40.0       21.0         375.0        €375
# 2380     68.0       45.0         650.0        €650
# 2574     45.0       40.0         750.0        €750
# 2619     21.0       24.0         270.0        €270
# 2628     25.0       46.0         950.0        €950
# 2666     45.0       46.0         950.0        €950
# 2706     45.0       27.0         270.0        €270
# 2817     62.0       58.0         550.0        €550
# 2821     39.0       72.0         270.0        €270
# 2834     40.0       23.0         950.0        €950
# 2940     45.0       23.0         270.0        €270
# 3043     31.0       36.0         550.0        €550
# 3089     53.0       15.0         270.0        €270
# 3096     60.0       60.0         270.0        €270
# ...       ...        ...           ...         ...
# 18176    40.0       46.0          40.0         €40
# 18177    41.0       55.0          70.0         €70
# 18178    18.0       12.0          50.0         €50
# 18179    27.0       32.0          50.0         €50
# 18180    20.0       29.0          40.0         €40
# 18181    37.0       33.0          50.0         €50
# 18182    45.0       44.0          50.0         €50
# 18184    46.0       37.0          40.0         €40
# 18185    49.0       40.0          50.0         €50
# 18186    50.0       43.0          60.0         €60
# 18187    38.0       47.0          40.0         €40
# 18188    47.0       36.0          60.0         €60
# 18189    41.0       48.0          60.0         €60
# 18190    54.0       34.0          60.0         €60
# 18191    39.0       29.0          50.0         €50
# 18192    45.0       33.0          50.0         €50
# 18193    30.0       32.0          50.0         €50
# 18194    28.0       16.0          50.0         €50
# 18195    40.0       35.0          60.0         €60
# 18196    51.0       44.0          60.0         €60
# 18197    48.0       49.0          60.0         €60
# 18198    37.0       14.0          60.0         €60
# 18199    40.0       36.0          70.0         €70
# 18200    37.0       58.0          60.0         €60
# 18201    31.0       38.0          60.0         €60
# 18202    52.0       43.0          60.0         €60
# 18203    33.0       43.0          60.0         €60
# 18204    43.0       55.0          60.0         €60
# 18205    47.0       50.0          60.0         €60
# 18206    49.0       33.0          60.0         €60
#
# [11108 rows x 22 columns]

# %%
#Idea completa para asignar miles y millones
#animals[animals.animal.str.contains('bat')]

g = lambda x : re.sub(r'(€|K)','',str(x)) #esto esta mal porque ahora se confunden los miles y los millones
fifa['ValueMiles'] = fifa[fifa.Value.str.contains('K')].Value.apply(g)

# %%
fifa.tail(100)
# Out:
#                        Name  Age          Nationality  Overall  Potential  \
# 18107          A. Osmanoski   18        FYR Macedonia       50         66
# 18108              J. Kelly   17  Republic of Ireland       50         66
# 18109         O. Ollikainen   17              Finland       50         64
# 18110              G. Tegue   18             Colombia       50         68
# 18111          J. Lindstrøm   18              Denmark       50         65
# 18112             Chen Zhao   21             China PR       50         61
# 18113            R. Pasquel   22               Mexico       50         60
# 18114          M. Al Qaydhi   20         Saudi Arabia       50         58
# 18115              O. Olsen   17              Denmark       50         67
# 18116          K. Moesgaard   21              Denmark       50         61
# 18117            T. Callens   19               France       50         65
# 18118            D. Collins   17  Republic of Ireland       49         62
# 18119               J. Egan   19              England       49         62
# 18120           Xie Xiaofan   20             China PR       49         61
# 18121            B. Buckley   17              England       49         61
# 18122          G. Figliuzzi   17                Italy       49         69
# 18123             O. Finney   20              England       49         63
# 18124          G. Hollywood   16  Republic of Ireland       49         67
# 18125             Zhu Jiayi   19             China PR       49         62
# 18126        B. Sass-Davies   18                Wales       49         70
# 18127            N. Stephan   17              Germany       49         67
# 18128          J. Greatorex   18              England       49         66
# 18129              J. James   18  Republic of Ireland       49         67
# 18130     F. Sinclair-Smith   17              England       49         67
# 18131           T. O'Connor   17  Republic of Ireland       49         59
# 18132            Liu Yaoxin   20             China PR       49         57
# 18133        M. Finne Wørts   19              Denmark       49         61
# 18134          F. Ranocchia   17                Italy       49         72
# 18135            N. Morahan   18  Republic of Ireland       49         68
# 18136             A. Kelsey   18              England       49         65
# ...                     ...  ...                  ...      ...        ...
# 18177             R. Roache   18  Republic of Ireland       48         69
# 18178          L. Wahlstedt   18               Sweden       48         65
# 18179           J. Williams   17              England       48         64
# 18180              M. Hurst   22             Scotland       48         58
# 18181              C. Maher   17  Republic of Ireland       48         66
# 18182               Y. Góez   18             Colombia       48         65
# 18183         K. Pilkington   44              England       48         48
# 18184             D. Horton   18              England       48         55
# 18185              E. Tweed   19  Republic of Ireland       48         59
# 18186          Zhang Yufeng   20             China PR       47         64
# 18187             C. Ehlich   19              Germany       47         59
# 18188            L. Collins   17                Wales       47         62
# 18189            A. Kaltner   18              Germany       47         61
# 18190            L. Watkins   18              England       47         67
# 18191  J. Norville-Williams   18              England       47         65
# 18192             S. Squire   18              England       47         64
# 18193            N. Fuentes   18                Chile       47         64
# 18194              J. Milli   18                Italy       47         65
# 18195            S. Griffin   18  Republic of Ireland       47         67
# 18196           K. Fujikawa   19                Japan       47         61
# 18197            D. Holland   18  Republic of Ireland       47         61
# 18198            J. Livesey   18              England       47         70
# 18199          M. Baldisimo   18               Canada       47         69
# 18200              J. Young   18             Scotland       47         62
# 18201              D. Walsh   18  Republic of Ireland       47         68
# 18202          J. Lundstram   19              England       47         65
# 18203    N. Christoffersson   19               Sweden       47         63
# 18204             B. Worman   16              England       47         67
# 18205        D. Walker-Rice   17              England       47         66
# 18206             G. Nugent   16              England       46         66
#
#                                 Club Value Preferred Foot Position  Weak Foot  \
# 18107             SpVgg Unterhaching  €60K          Right       CM        3.0
# 18108                 Bray Wanderers  €50K          Right       GK        1.0
# 18109                   HJK Helsinki  €60K          Right       CM        3.0
# 18110         Independiente Medellín  €50K           Left       CB        3.0
# 18111                     Brøndby IF  €60K          Right      CAM        3.0
# 18112  Shanghai Greenland Shenhua FC  €40K          Right       GK        2.0
# 18113               Deportivo Toluca  €40K          Right       GK        2.0
# 18114                        Al Raed  €40K           Left       CB        3.0
# 18115                 FC Midtjylland  €50K          Right      RWB        3.0
# 18116                     Esbjerg fB  €50K          Right       LM        2.0
# 18117            Stade Malherbe Caen  €50K           Left       GK        3.0
# 18118                   Sligo Rovers  €50K          Right       LM        3.0
# 18119                Carlisle United  €60K          Right       RM        2.0
# 18120              Jiangsu Suning FC  €50K          Right       CM        3.0
# 18121                   Grimsby Town  €50K          Right      CAM        3.0
# 18122                        Crotone  €50K          Right       GK        2.0
# 18123                Crewe Alexandra  €60K           Left       CM        3.0
# 18124                 Bray Wanderers  €60K          Right       CM        2.0
# 18125               Shanghai SIPG FC  €50K          Right       CB        3.0
# 18126                Crewe Alexandra  €60K          Right       CB        3.0
# 18127          FC Würzburger Kickers  €50K          Right       GK        3.0
# 18128                       Barnsley  €50K          Right       GK        2.0
# 18129                     Luton Town  €50K          Right       RB        3.0
# 18130                      Blackpool  €60K          Right       ST        3.0
# 18131                    Limerick FC  €40K          Right       CB        2.0
# 18132                Tianjin TEDA FC  €40K          Right       CM        2.0
# 18133                FC Nordsjælland  €50K          Right       CB        3.0
# 18134                        Perugia  €60K          Right       CM        4.0
# 18135                   Sligo Rovers  €60K          Right       CM        3.0
# 18136              Scunthorpe United  €50K          Right       GK        2.0
# ...                              ...   ...            ...      ...        ...
# 18177                      Blackpool  €70K          Right       ST        3.0
# 18178                     Dalkurd FF  €50K          Right       GK        2.0
# 18179               Northampton Town  €50K          Right       CB        3.0
# 18180               St. Johnstone FC  €40K          Right       GK        2.0
# 18181                 Bray Wanderers  €50K          Right       RB        2.0
# 18182              Atlético Nacional  €50K          Right      CDM        3.0
# 18183               Cambridge United    €0          Right       GK        2.0
# 18184                   Lincoln City  €40K          Right       CM        3.0
# 18185                     Derry City  €50K          Right      LCM        3.0
# 18186               Beijing Renhe FC  €60K          Right       CM        3.0
# 18187             SpVgg Unterhaching  €40K          Right       RB        3.0
# 18188                 Newport County  €60K          Right       CM        3.0
# 18189             SpVgg Unterhaching  €60K          Right       ST        3.0
# 18190               Cambridge United  €60K          Right       CM        3.0
# 18191               Cambridge United  €50K           Left       LB        3.0
# 18192               Cambridge United  €50K          Right      CDM        3.0
# 18193                 Unión Española  €50K          Right       RB        2.0
# 18194                          Lecce  €50K          Right       GK        3.0
# 18195                   Waterford FC  €60K          Right       CM        3.0
# 18196                   Júbilo Iwata  €60K          Right       CM        3.0
# 18197                      Cork City  €60K          Right       CM        3.0
# 18198                  Burton Albion  €60K          Right       GK        2.0
# 18199         Vancouver Whitecaps FC  €70K          Right       CM        3.0
# 18200                   Swindon Town  €60K           Left       ST        2.0
# 18201                   Waterford FC  €60K           Left       RB        3.0
# 18202                Crewe Alexandra  €60K          Right       CM        2.0
# 18203                 Trelleborgs FF  €60K          Right       ST        2.0
# 18204               Cambridge United  €60K          Right       ST        3.0
# 18205                Tranmere Rovers  €60K          Right       RW        3.0
# 18206                Tranmere Rovers  €60K          Right       CM        3.0
#
#        ...  Stamina  Strength  LongShots  Aggression  Interceptions  \
# 18107  ...     63.0      63.0       36.0        53.0           43.0
# 18108  ...     28.0      34.0        7.0        20.0            7.0
# 18109  ...     56.0      42.0       40.0        54.0           38.0
# 18110  ...     61.0      57.0       18.0        43.0           53.0
# 18111  ...     49.0      34.0       32.0        49.0           27.0
# 18112  ...     22.0      75.0        7.0        16.0            6.0
# 18113  ...     21.0      46.0        5.0        26.0           12.0
# 18114  ...     61.0      43.0       17.0        43.0           45.0
# 18115  ...     54.0      63.0       27.0        54.0           47.0
# 18116  ...     50.0      44.0       38.0        27.0           30.0
# 18117  ...     18.0      51.0        9.0        26.0           13.0
# 18118  ...     31.0      35.0       44.0        37.0           22.0
# 18119  ...     50.0      54.0       34.0        33.0           17.0
# 18120  ...     55.0      74.0       33.0        59.0           41.0
# 18121  ...     45.0      50.0       38.0        40.0           36.0
# 18122  ...     18.0      66.0        8.0        18.0            7.0
# 18123  ...     49.0      34.0       33.0        33.0           26.0
# 18124  ...     48.0      43.0       38.0        44.0           21.0
# 18125  ...     60.0      67.0       16.0        42.0           48.0
# 18126  ...     53.0      65.0       16.0        49.0           51.0
# 18127  ...     23.0      58.0        6.0        27.0            9.0
# 18128  ...     19.0      51.0        7.0        19.0           11.0
# 18129  ...     66.0      45.0       24.0        44.0           46.0
# 18130  ...     42.0      41.0       37.0        30.0           23.0
# 18131  ...     57.0      54.0       24.0        47.0           51.0
# 18132  ...     61.0      39.0       39.0        59.0           41.0
# 18133  ...     55.0      56.0       25.0        47.0           51.0
# 18134  ...     44.0      59.0       28.0        61.0           45.0
# 18135  ...     53.0      38.0       45.0        52.0           48.0
# 18136  ...     28.0      50.0        7.0        16.0            9.0
# ...    ...      ...       ...        ...         ...            ...
# 18177  ...     51.0      44.0       41.0        25.0           13.0
# 18178  ...     20.0      38.0        6.0        20.0           10.0
# 18179  ...     55.0      54.0       20.0        47.0           47.0
# 18180  ...     33.0      58.0       20.0        20.0           29.0
# 18181  ...     60.0      48.0       33.0        53.0           46.0
# 18182  ...     54.0      48.0       25.0        50.0           48.0
# 18183  ...     22.0      44.0       12.0        24.0           15.0
# 18184  ...     59.0      66.0       31.0        53.0           49.0
# 18185  ...     60.0      43.0       30.0        52.0           45.0
# 18186  ...     46.0      60.0       34.0        55.0           43.0
# 18187  ...     61.0      59.0       41.0        38.0           36.0
# 18188  ...     33.0      40.0       36.0        36.0           36.0
# 18189  ...     55.0      60.0       35.0        28.0           25.0
# 18190  ...     61.0      55.0       34.0        44.0           44.0
# 18191  ...     38.0      55.0       25.0        55.0           55.0
# 18192  ...     55.0      59.0       36.0        55.0           44.0
# 18193  ...     54.0      40.0       22.0        48.0           49.0
# 18194  ...     15.0      59.0        5.0        17.0            5.0
# 18195  ...     54.0      49.0       30.0        51.0           35.0
# 18196  ...     35.0      51.0       30.0        55.0           44.0
# 18197  ...     50.0      38.0       37.0        37.0           28.0
# 18198  ...     20.0      38.0        5.0        25.0            6.0
# 18199  ...     42.0      43.0       30.0        53.0           49.0
# 18200  ...     31.0      31.0       51.0        26.0           16.0
# 18201  ...     39.0      52.0       16.0        44.0           45.0
# 18202  ...     40.0      47.0       38.0        46.0           46.0
# 18203  ...     43.0      67.0       42.0        47.0           16.0
# 18204  ...     55.0      32.0       45.0        32.0           15.0
# 18205  ...     40.0      48.0       34.0        33.0           22.0
# 18206  ...     47.0      60.0       32.0        56.0           42.0
#
#        Positioning  Vision  Penalties  ValueNumeric  ValueMiles
# 18107         50.0    44.0       38.0          60.0          60
# 18108          7.0    36.0       14.0          50.0          50
# 18109         55.0    42.0       37.0          60.0          60
# 18110         24.0    30.0       37.0          50.0          50
# 18111         39.0    56.0       45.0          60.0          60
# 18112          6.0    40.0       12.0          40.0          40
# 18113          6.0    38.0       14.0          40.0          40
# 18114         34.0    32.0       41.0          40.0          40
# 18115         48.0    31.0       35.0          50.0          50
# 18116         46.0    41.0       40.0          50.0          50
# 18117          8.0    36.0       16.0          50.0          50
# 18118         49.0    52.0       40.0          50.0          50
# 18119         49.0    47.0       47.0          60.0          60
# 18120         48.0    46.0       39.0          50.0          50
# 18121         41.0    55.0       35.0          50.0          50
# 18122          6.0    30.0       12.0          50.0          50
# 18123         49.0    48.0       29.0          60.0          60
# 18124         48.0    51.0       48.0          60.0          60
# 18125         25.0    33.0       38.0          50.0          50
# 18126         27.0    33.0       35.0          60.0          60
# 18127          5.0    36.0       15.0          50.0          50
# 18128          7.0    23.0       15.0          50.0          50
# 18129         37.0    33.0       31.0          50.0          50
# 18130         48.0    45.0       48.0          60.0          60
# 18131         20.0    26.0       33.0          40.0          40
# 18132         46.0    45.0       35.0          40.0          40
# 18133         23.0    38.0       31.0          50.0          50
# 18134         35.0    51.0       44.0          60.0          60
# 18135         48.0    48.0       38.0          60.0          60
# 18136          6.0    26.0       17.0          50.0          50
# ...            ...     ...        ...           ...         ...
# 18177         48.0    41.0       55.0          70.0          70
# 18178          7.0    18.0       12.0          50.0          50
# 18179         28.0    27.0       32.0          50.0          50
# 18180         13.0    20.0       29.0          40.0          40
# 18181         43.0    37.0       33.0          50.0          50
# 18182         25.0    45.0       44.0          50.0          50
# 18183         10.0    11.0       22.0           0.0         NaN
# 18184         35.0    46.0       37.0          40.0          40
# 18185         35.0    49.0       40.0          50.0          50
# 18186         29.0    50.0       43.0          60.0          60
# 18187         44.0    38.0       47.0          40.0          40
# 18188         44.0    47.0       36.0          60.0          60
# 18189         43.0    41.0       48.0          60.0          60
# 18190         51.0    54.0       34.0          60.0          60
# 18191         47.0    39.0       29.0          50.0          50
# 18192         38.0    45.0       33.0          50.0          50
# 18193         35.0    30.0       32.0          50.0          50
# 18194          3.0    28.0       16.0          50.0          50
# 18195         47.0    40.0       35.0          60.0          60
# 18196         28.0    51.0       44.0          60.0          60
# 18197         39.0    48.0       49.0          60.0          60
# 18198          5.0    37.0       14.0          60.0          60
# 18199         35.0    40.0       36.0          70.0          70
# 18200         46.0    37.0       58.0          60.0          60
# 18201         20.0    31.0       38.0          60.0          60
# 18202         39.0    52.0       43.0          60.0          60
# 18203         46.0    33.0       43.0          60.0          60
# 18204         48.0    43.0       55.0          60.0          60
# 18205         44.0    47.0       50.0          60.0          60
# 18206         34.0    49.0       33.0          60.0          60
#
# [100 rows x 22 columns]

# %% [markdown]
# #### We'd like to determine whether a player's preffered foot and position have an impact on their value.
#
# Using the `statsmodels` library, we are able to produce an ANOVA table without munging our data. Create an ANOVA table with value as a function of position and preferred foot. Recall that pivoting is performed by the `C` function.
#
# Hint: For columns that have a space in their name, it is best to refer to the column using the dataframe (For example: for column `A`, we will use `df['A']`).

# %%
#Importamos las bibliotecas necesarios
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
#Cambiemos el nombre de la columna Preferred Foot
fifa.rename(columns={'Preferred Foot':'Preferred_foot'}, inplace=True)

# %%
model = ols('Value ~ C(Preferred_foot) + C(Position)', data=fifa).fit() # C es la función que hace el pivote interno
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table

# %% [markdown]
# What is your conclusion from this ANOVA?

# %%
# Your conclusions here:
'''
Respecto al pie preferido hay 2 grados de libertad y el p value es 0.35 > 0.05 lo cual lo hace insuficiente para ser significativo estadśiticamente
Respecto a la posición el p-value es mucho menor que 0.05 por lo cual sí tiene significancia estadística la posición en la que se juegue
'''

# %% [markdown]
# After looking at a model of both preffered foot and position, we decide to create an ANOVA table for nationality. Create an ANOVA table for numeric value as a function of nationality.

# %%
# Your code here:
model2 = ols('Value ~ C(Nationality)', data=fifa).fit() # C es la función que hace el pivote interno
anova_table = sm.stats.anova_lm(model2, typ=2)
anova_table

# %% [markdown]
# What is your conclusion from this ANOVA?

# %%
'''
En este caso el p-value también es mucho más pequeño que 0.05 por lo que rechazamos la hipótesis nula de que la nacionalidad sí tiene que ver
'''

# %% [markdown]
# # Challenge 2 - Linear Regression
#
# Our goal with using linear regression is to create a mathematical model that will enable us to predict the outcome of one variable using one or more additional independent variables.
#
# We'll start by ensuring there are no missing values. Examine all variables for all missing values. If there are missing values in a row, remove the entire row.

# %%
# Your code here:
from scipy.stats import linregress

# %%
fifa4 = fifa
# fifa4 = fifa4[fifa4.isna().sum(axis=1) == 0] forma super eficiente de borrar las columnas

# %%
fifa4

# %%
fifa4.drop(columns=['Club','Preferred_foot','Position','Weak Foot','Acceleration', 'SprintSpeed','Stamina','Strength','LongShots','Aggression', 'Interceptions','Positioning','Vision','Penalties'], inplace=True)

# %%
fifa4.head(1)

# %% [markdown]
# Using the FIFA dataset, in the cell below, create a linear model predicting value using stamina and sprint speed. create the model using `statsmodels`. Print the model summary.
#
# Hint: remember to add an intercept to the model using the `add_constant` function.

# %%
#Esto no debería estar aquí, pero lo pongo para probar
fifa = pd.read_csv('fifa.csv')
fifa["ValueNumeric"] = fifa["Value"].str.replace("€", "").str.replace("M","").str.replace("K","").astype(float)

# %%
# Your code here:
X = sm.add_constant(fifa[['SprintSpeed', 'Stamina']])
Y = fifa.ValueNumeric

model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 

print(model.summary())

# %% [markdown]
# Report your findings from the model summary. In particular, report about the model as a whole using the F-test and how much variation is predicted by the model using the r squared.

# %%
# Your conclusions here:

# %% [markdown]
# Next, create a second regression model predicting value using potential. Create the model using `statsmodels` and print the model summary. Remember to add a constant term.

# %%
# Your code here:

# %% [markdown]
# Report your findings from the model summary. In particular, report about the model as a whole using the F-test and how much variation is predicted by the model using the r squared.

# %%
# Your conclusions here:

# %% [markdown]
# Plot a scatter plot of value vs. potential. Do you see a linear relationship?

# %%
# Your code here:
