# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# %matplotlib inline
# import numpy and pandas

import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt

from scipy.stats import f_oneway, f

import statsmodels.api as sm
from statsmodels.formula.api import ols

import warnings
warnings.simplefilter('ignore')
import re

# %% [markdown]
# # Challenge 1 - Analysis of Variance
#
# In this part of the lesson, we will perform an analysis of variance to determine whether the factors in our model create a significant difference in the group means. We will be examining a dataset of FIFA players. We'll start by loading the data using the code in the cell below.

# %%
# Run this code:

fifa = pd.read_csv('fifa.csv')

# %% [markdown]
# Let's examine the dataset by looking at the `head`.

# %%
# Your code here:
fifa.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
#
#                   Club    Value Preferred Foot Position  Weak Foot  \
# 0         FC Barcelona  €110.5M           Left       RF        4.0
# 1             Juventus     €77M          Right       ST        4.0
# 2  Paris Saint-Germain  €118.5M          Right       LW        5.0
# 3    Manchester United     €72M          Right       GK        3.0
# 4      Manchester City    €102M          Right      RCM        5.0
#
#    Acceleration  SprintSpeed  Stamina  Strength  LongShots  Aggression  \
# 0          91.0         86.0     72.0      59.0       94.0        48.0
# ...

# %% [markdown]
# Player's values are expressed in millions of euros. We would like this column to be numeric. Therefore, let's create a numeric value column. Do this by stripping all non-numeric characters from each cell. Assign this new data to `ValueNumeric`. There is no need to multiply the value to be expressed in millions.

# %%
# Your code here:
fifa_data = fifa.copy()

salary_to_clean = fifa_data['Value'].values
salary_to_clean
# Out:
# array(['€110.5M', '€77M', '€118.5M', ..., '€60K', '€60K', '€60K'],
#       dtype=object)

# %%
text_to_clean_list = list(salary_to_clean)
text_cleaned = [(re.sub("[^A-Za-z0-9M]","",i)) for i in text_to_clean_list ]
text_cleaned
# Out:
# ['1105M',
#  '77M',
#  '1185M',
#  '72M',
#  '102M',
#  '93M',
#  '67M',
#  '80M',
#  '51M',
#  '68M',
#  '77M',
#  '765M',
#  '44M',
#  '60M',
#  '63M',
#  '89M',
#  '835M',
#  '78M',
#  '58M',
#  '535M',
#  '515M',
#  '60M',
#  '38M',
#  '645M',
#  '27M',
#  '81M',
#  '695M',
#  '595M',
#  '695M',
#  '62M',
#  '735M',
#  '735M',
#  '695M',
#  '59M',
#  '46M',
#  '43M',
#  '60M',
#  '36M',
#  '57M',
#  '24M',
#  '30M',
#  '4M',
#  '57M',
#  '645M',
#  '51M',
#  '64M',
#  '305M',
#  '625M',
#  '52M',
#  '38M',
#  '45M',
#  '34M',
#  '465M',
#  '465M',
#  '34M',
#  '61M',
#  '595M',
#  '415M',
#  '52M',
#  '445M',
#  '565M',
#  '53M',
#  '50M',
#  '55M',
#  '365M',
#  '465M',
#  '45M',
#  '455M',
#  '435M',
#  '35M',
#  '30M',
#  '39M',
#  '44M',
#  '30M',
#  '435M',
#  '18M',
#  '215M',
#  '465M',
#  '505M',
#  '54M',
#  '50M',
#  '365M',
#  '405M',
#  '505M',
#  '405M',
#  '38M',
#  '45M',
#  '45M',
#  '375M',
#  '285M',
#  '37M',
#  '37M',
#  '32M',
#  '375M',
#  '39M',
#  '30M',
# ...

# %%
def remove_non_numeric(x):
    if x[-1] == 'M':
        y = float(re.sub('[^0-9\\.]', '', x))
        z = y*10**6
        return(z)
    elif x[-1] == 'K':
        y = float(re.sub('[^0-9\\.]', '', x))
        z = y*10**3
        return(z)
fifa['ValueNumeric'] = fifa['Value'].apply(remove_non_numeric)

# %%
fifa.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
#
#                   Club    Value Preferred Foot Position  Weak Foot  ...  \
# 0         FC Barcelona  €110.5M           Left       RF        4.0  ...
# 1             Juventus     €77M          Right       ST        4.0  ...
# 2  Paris Saint-Germain  €118.5M          Right       LW        5.0  ...
# 3    Manchester United     €72M          Right       GK        3.0  ...
# 4      Manchester City    €102M          Right      RCM        5.0  ...
#
#    SprintSpeed  Stamina  Strength  LongShots  Aggression  Interceptions  \
# 0         86.0     72.0      59.0       94.0        48.0           22.0
# ...

# %% [markdown]
# #### We'd like to determine whether a player's preffered foot and position have an impact on their value.
#
# Using the `statsmodels` library, we are able to produce an ANOVA table without munging our data. Create an ANOVA table with value as a function of position and preferred foot. Recall that pivoting is performed by the `C` function.
#
# Hint: For columns that have a space in their name, it is best to refer to the column using the dataframe (For example: for column `A`, we will use `df['A']`).

# %%
# Your code here:
formula = 'ValueNumeric ~ C(fifa["Preferred Foot"]) + C(Position)'
modelo = ols(formula=formula, data=fifa).fit()
anova_table = sm.stats.anova_lm(modelo, typ=2)
anova_table
# Out:
#                                  sum_sq       df          F        PR(>F)
# C(fifa["Preferred Foot"])  2.316461e+14      1.0   7.510257  6.140953e-03
# C(Position)                1.659610e+16     26.0  20.694853  1.699733e-95
# Residual                   5.514593e+17  17879.0        NaN           NaN

# %% [markdown]
# What is your conclusion from this ANOVA?

# %%
# Your conclusions here:
# Se puede concluir que el P value es menor que 0.05, por lo que podemos 
#rechazar la hipotesis nula asi mismo, es posible tener diferencias 
#signifiactivas entre la pierna preferida, la posicion y el valor del jugador

# %% [markdown]
# After looking at a model of both preffered foot and position, we decide to create an ANOVA table for nationality. Create an ANOVA table for numeric value as a function of nationality.

# %%
# Your code here:
formula = 'ValueNumeric ~ C(fifa["Nationality"])'
modelo = ols(formula=formula, data=fifa).fit()
anova_table = sm.stats.anova_lm(modelo, typ=1)
anova_table
# Out:
#                              df        sum_sq       mean_sq         F  \
# C(fifa["Nationality"])    162.0  3.281695e+16  2.025738e+14  6.713684
# Residual                17744.0  5.353945e+17  3.017327e+13       NaN
#
#                                PR(>F)
# C(fifa["Nationality"])  8.383689e-132
# Residual                          NaN

# %%
#El valor de ANOVA es mas pequeno que 0.05, en este caso rechazamos 
#la hipotesis nula y es posible decir que la nacionalidad no esta
#relacionada con el valor del jugador.

# %% [markdown]
# What is your conclusion from this ANOVA?

# %% [markdown]
# # Challenge 2 - Linear Regression
#
# Our goal with using linear regression is to create a mathematical model that will enable us to predict the outcome of one variable using one or more additional independent variables.
#
# We'll start by ensuring there are no missing values. Examine all variables for all missing values. If there are missing values in a row, remove the entire row.

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17907 entries, 0 to 18206
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            17907 non-null  object
#  1   Age             17907 non-null  int64
#  2   Nationality     17907 non-null  object
#  3   Overall         17907 non-null  int64
#  4   Potential       17907 non-null  int64
#  5   Club            17907 non-null  object
#  6   Value           17907 non-null  object
#  7   Preferred Foot  17907 non-null  object
#  8   Position        17907 non-null  object
#  9   Weak Foot       17907 non-null  float64
#  10  Acceleration    17907 non-null  float64
#  11  SprintSpeed     17907 non-null  float64
#  12  Stamina         17907 non-null  float64
#  13  Strength        17907 non-null  float64
#  14  LongShots       17907 non-null  float64
#  15  Aggression      17907 non-null  float64
#  16  Interceptions   17907 non-null  float64
# ...

# %%
#Solo para eliminar filas 
fifa = fifa.dropna()

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17907 entries, 0 to 18206
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            17907 non-null  object
#  1   Age             17907 non-null  int64
#  2   Nationality     17907 non-null  object
#  3   Overall         17907 non-null  int64
#  4   Potential       17907 non-null  int64
#  5   Club            17907 non-null  object
#  6   Value           17907 non-null  object
#  7   Preferred Foot  17907 non-null  object
#  8   Position        17907 non-null  object
#  9   Weak Foot       17907 non-null  float64
#  10  Acceleration    17907 non-null  float64
#  11  SprintSpeed     17907 non-null  float64
#  12  Stamina         17907 non-null  float64
#  13  Strength        17907 non-null  float64
#  14  LongShots       17907 non-null  float64
#  15  Aggression      17907 non-null  float64
#  16  Interceptions   17907 non-null  float64
# ...

# %% [markdown]
# Using the FIFA dataset, in the cell below, create a linear model predicting value using stamina and sprint speed. create the model using `statsmodels`. Print the model summary.
#
# Hint: remember to add an intercept to the model using the `add_constant` function.

# %%
# Your code here:
import statsmodels.api as sm
from statsmodels.formula.api import ols
from scipy.stats import linregress
import seaborn as sns

# %%
fifa.corr()
sns.heatmap(fifa.corr(), annot=True, cmap='coolwarm');

# %%
#stamina and sprint speed ;tienen una correlacion  con value numeric de 0,27 y 02,6

x = sm.add_constant(fifa[['Stamina','SprintSpeed']].values)            
y = fifa['ValueNumeric']
modelo = sm.OLS(y, x).fit() # Esto es la regresión lineal
modelo.summary()   #Revisar R-squared y Adj R-Squared
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           ValueNumeric   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                     452.2
# Date:                Thu, 30 Sep 2021   Prob (F-statistic):          2.64e-192
# Time:                        12:16:00   Log-Likelihood:            -3.0332e+05
# No. Observations:               17907   AIC:                         6.066e+05
# Df Residuals:                   17904   BIC:                         6.067e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -3.072e+06   1.97e+05    -15.576      0.000   -3.46e+06   -2.69e+06
# ...

# %% [markdown]
# Report your findings from the model summary. In particular, report about the model as a whole using the F-test and how much variation is predicted by the model using the r squared.

# %%
# Your conclusions here:
#El valor de R al cuadrado es muy bajo, por lo que el poder de prediccion de nuestro modelo 
#es muy bajo

# %% [markdown]
# Next, create a second regression model predicting value using potential. Create the model using `statsmodels` and print the model summary. Remember to add a constant term.

# %%
# Your code here:
x = sm.add_constant(fifa[['Potential']].values)            
y = fifa['ValueNumeric']
modelo = sm.OLS(y, x).fit() # Esto es la regresión lineal
modelo.summary()   #Revisar R-squared y Adj R-Squared
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           ValueNumeric   R-squared:                       0.336
# Model:                            OLS   Adj. R-squared:                  0.336
# Method:                 Least Squares   F-statistic:                     9073.
# Date:                Thu, 30 Sep 2021   Prob (F-statistic):               0.00
# Time:                        12:18:49   Log-Likelihood:            -3.0009e+05
# No. Observations:               17907   AIC:                         6.002e+05
# Df Residuals:                   17905   BIC:                         6.002e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -3.552e+07      4e+05    -88.778      0.000   -3.63e+07   -3.47e+07
# ...

# %% [markdown]
# Report your findings from the model summary. In particular, report about the model as a whole using the F-test and how much variation is predicted by the model using the r squared.

# %%
# Your conclusions here:
#El valor de R al cuadrado es muy bajo, por lo que el poder de prediccion de nuestro modelo 
#sigue siendo muy bajo

# %% [markdown]
# Plot a scatter plot of value vs. potential. Do you see a linear relationship?

# %%
# Your code here:

import plotly.express as px

plt.scatter(fifa['Potential'],fifa['ValueNumeric'], marker='x')
plt.show()

# %%
#Se confirma que la relacion entre Potential y ValueNumeric no es lineal, sino exponencial.
