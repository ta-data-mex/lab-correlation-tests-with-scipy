# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# %matplotlib inline
# import numpy and pandas

import numpy as np
import pandas as pd

import statsmodels.api as sm
from statsmodels.formula.api import ols

from scipy.stats import linregress

import matplotlib.pyplot as plt

# %% [markdown]
# # Challenge 1 - Analysis of Variance
#
# In this part of the lesson, we will perform an analysis of variance to determine whether the factors in our model create a significant difference in the group means. We will be examining a dataset of FIFA players. We'll start by loading the data using the code in the cell below.

# %%
# Run this code:

fifa = pd.read_csv('fifa.csv')

# %% [markdown]
# Let's examine the dataset by looking at the `head`.

# %%
# Your code here:

fifa.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
#
#                   Club    Value Preferred Foot Position  Weak Foot  \
# 0         FC Barcelona  €110.5M           Left       RF        4.0
# 1             Juventus     €77M          Right       ST        4.0
# 2  Paris Saint-Germain  €118.5M          Right       LW        5.0
# 3    Manchester United     €72M          Right       GK        3.0
# 4      Manchester City    €102M          Right      RCM        5.0
#
#    Acceleration  SprintSpeed  Stamina  Strength  LongShots  Aggression  \
# 0          91.0         86.0     72.0      59.0       94.0        48.0
# ...

# %% [markdown]
# Player's values are expressed in millions of euros. We would like this column to be numeric. Therefore, let's create a numeric value column. Do this by stripping all non-numeric characters from each cell. Assign this new data to `ValueNumeric`. There is no need to multiply the value to be expressed in millions.

# %%
# Your code here:

fifa['ValueNumeric'] = fifa['Value'].apply(lambda x: float(x[1:-1]) if x[1] != '0' else float(x[-1]))
fifa['ValueNumeric'].unique()
# Out:
# array([110.5,  77. , 118.5,  72. , 102. ,  93. ,  67. ,  80. ,  51. ,
#         68. ,  76.5,  44. ,  60. ,  63. ,  89. ,  83.5,  78. ,  58. ,
#         53.5,  51.5,  38. ,  64.5,  27. ,  81. ,  69.5,  59.5,  62. ,
#         73.5,  59. ,  46. ,  43. ,  36. ,  57. ,  24. ,  30. ,   4. ,
#         64. ,  30.5,  62.5,  52. ,  45. ,  34. ,  46.5,  61. ,  41.5,
#         44.5,  56.5,  53. ,  50. ,  55. ,  36.5,  45.5,  43.5,  35. ,
#         39. ,  18. ,  21.5,  50.5,  54. ,  40.5,  37.5,  28.5,  37. ,
#         32. ,  26. ,  33. ,  38.5,  35.5,   9. ,  15.5,  22. ,  14. ,
#         42.5,  31.5,  42. ,  25. ,  29.5,  31. ,  24.5,  27.5,  29. ,
#         16.5,  23. ,  19. ,   4.2,  40. ,  41. ,  28. ,  22.5,  34.5,
#         32.5,  20. ,  26.5,  25.5,  21. ,  13. ,  17.5,  11.5,   8. ,
#          6. ,  19.5,   6.5,  20.5,  23.5,  18.5,  17. ,  12.5,  15. ,
#         13.5,   4.8,   3. ,   1.5,  16. ,  10. ,  11. ,   7. ,  14.5,
# ...

# %% [markdown]
# #### We'd like to determine whether a player's preffered foot and position have an impact on their value.
#
# Using the `statsmodels` library, we are able to produce an ANOVA table without munging our data. Create an ANOVA table with value as a function of position and preferred foot. Recall that pivoting is performed by the `C` function.
#
# Hint: For columns that have a space in their name, it is best to refer to the column using the dataframe (For example: for column `A`, we will use `df['A']`).

# %%
# Your code here:
# Tenemos que usar un ANOVA de dos vias ya que tenemos dos variables independiente (preffered foot and position) y una
# dependiente el precio

formula = 'ValueNumeric ~ C(Position) + C(fifa["Preferred Foot"])'

modelo = ols(formula=formula, data=fifa).fit()

anova_table = sm.stats.anova_lm(modelo, typ=2)

anova_table
# Out:
#                                  sum_sq       df         F        PR(>F)
# C(Position)                8.767522e+06     26.0  4.031426  2.192419e-11
# C(fifa["Preferred Foot"])  7.292211e+04      1.0  0.871795  3.504713e-01
# Residual                   1.515581e+09  18119.0       NaN           NaN

# %% [markdown]
# What is your conclusion from this ANOVA?

# %%
# Your conclusions here:

# H0 = las medias de las distintas posiciones y del pie preferido son iguales tomando como variable dependiente el
# precio del jugador

# Podemos ver que en lo que respecta a la posicion del jugador el p-value es menor a 0.05, por lo que la hipotesis nula
# queda rechazada, es decir, por lo menos en uno de los grupos de las posicion el valor medio del precio es diferente. Esto
# nos hace pensar que dependiente de la posicion el precio del jugador varia

# Por otro lado tenemos el pie preferido por el jugador. Vemos que el p-value es de 0.35 lo que es mayor a 0.05 lo que nos
# dice que la hipotesis nula se cumple y las medias para el pie izquierdo y derecho respecto al precio son las misma. Entonces
# se concluye que el pie preferido no tiene un impacto en el precio del jugador ya que la media de los precios es la misma

# %% [markdown]
# After looking at a model of both preffered foot and position, we decide to create an ANOVA table for nationality. Create an ANOVA table for numeric value as a function of nationality.

# %%
# Your code here:

formula = 'ValueNumeric ~ C(Nationality)'

modelo = ols(formula=formula, data=fifa).fit()

anova_table = sm.stats.anova_lm(modelo, typ=1)

anova_table
# Out:
#                      df        sum_sq        mean_sq         F        PR(>F)
# C(Nationality)    163.0  4.292914e+07  263368.987135  3.202987  1.976253e-38
# Residual        18043.0  1.483605e+09   82226.058289       NaN           NaN

# %% [markdown]
# What is your conclusion from this ANOVA?

# %%
# H0 = Los valores medios del precio por nacionalidad son iguales

# Obtenemos un p-value menor a 0.05, lo que nos dice que en al menos una nacionalidad tenemos un valor medio del precio
# diferente. Esto es interezante, ya que nos dice en un principio, que el precio varia dependiendo de la nacionalidad del 
# jugador.

# %% [markdown]
# # Challenge 2 - Linear Regression
#
# Our goal with using linear regression is to create a mathematical model that will enable us to predict the outcome of one variable using one or more additional independent variables.
#
# We'll start by ensuring there are no missing values. Examine all variables for all missing values. If there are missing values in a row, remove the entire row.

# %%
# Your code here:

fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            18207 non-null  object
#  1   Age             18207 non-null  int64
#  2   Nationality     18207 non-null  object
#  3   Overall         18207 non-null  int64
#  4   Potential       18207 non-null  int64
#  5   Club            17966 non-null  object
#  6   Value           18207 non-null  object
#  7   Preferred Foot  18159 non-null  object
#  8   Position        18147 non-null  object
#  9   Weak Foot       18159 non-null  float64
#  10  Acceleration    18159 non-null  float64
#  11  SprintSpeed     18159 non-null  float64
#  12  Stamina         18159 non-null  float64
#  13  Strength        18159 non-null  float64
#  14  LongShots       18159 non-null  float64
#  15  Aggression      18159 non-null  float64
#  16  Interceptions   18159 non-null  float64
# ...

# %%
fifa.isnull().sum()
# Out:
# Name                0
# Age                 0
# Nationality         0
# Overall             0
# Potential           0
# Club              241
# Value               0
# Preferred Foot     48
# Position           60
# Weak Foot          48
# Acceleration       48
# SprintSpeed        48
# Stamina            48
# Strength           48
# LongShots          48
# Aggression         48
# Interceptions      48
# Positioning        48
# Vision             48
# Penalties          48
# ValueNumeric        0
# dtype: int64

# %%
fifa_new = fifa.dropna() # Eliminamos las filas con valores nulos

# %% [markdown]
# Using the FIFA dataset, in the cell below, create a linear model predicting value using stamina and sprint speed. create the model using `statsmodels`. Print the model summary.
#
# Hint: remember to add an intercept to the model using the `add_constant` function.

# %%
# Your code here:

x = sm.add_constant(fifa_new[['Stamina', 'SprintSpeed']])
y = fifa_new['ValueNumeric']

modelo = sm.OLS(y, x).fit()
print(modelo.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           ValueNumeric   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     4.454
# Date:                Thu, 30 Sep 2021   Prob (F-statistic):             0.0116
# Time:                        14:09:05   Log-Likelihood:            -1.2702e+05
# No. Observations:               17918   AIC:                         2.540e+05
# Df Residuals:                   17915   BIC:                         2.541e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         280.4297     10.390     26.991      0.000     260.065     300.795
# ...

# %%
import plotly.express as px

fig = px.scatter_3d(fifa_new, x='SprintSpeed', y='Stamina', z='ValueNumeric')
fig.show()
# Out:
# <div>                            <div id="c541f257-17b5-4170-9959-43a9d5329b30" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c541f257-17b5-4170-9959-43a9d5329b30")) {                    Plotly.newPlot(                        "c541f257-17b5-4170-9959-43a9d5329b30",                        [{"hovertemplate":"SprintSpeed=%{x}<br>Stamina=%{y}<br>ValueNumeric=%{z}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"type":"scatter3d","x":[86.0,91.0,90.0,58.0,76.0,88.0,72.0,75.0,75.0,60.0,78.0,62.0,68.0,64.0,78.0,83.0,72.0,85.0,50.0,52.0,52.0,76.0,60.0,80.0,75.0,96.0,91.0,65.0,67.0,86.0,69.0,73.0,75.0,95.0,64.0,82.0,95.0,62.0,73.0,72.0,55.0,43.0,73.0,78.0,75.0,79.0
# ...

# %% [markdown]
# Report your findings from the model summary. In particular, report about the model as a whole using the F-test and how much variation is predicted by the model using the r squared.

# %%
# Your conclusions here:

# Podemos ver que el r2 es 0, es decir, con estas dos variables (sprint y stamina) se puede explicar un 0% de la variacion
# de lo datos del precio. Es decir, no nos dicen nada del comportamiento del precio y por lo tanto, sus cambios no estan 
# relacionados con el aumento o la caida del precio de los jugadores.

# En la grafica de 3 dimensiones podemos ver como no hay un comportamiento lineal entre las variables

# Por otro lado, nuesto p-value es menor a 0.05, por lo que rechazamos la hipotesis nula, lo que nos dice que la media
# de nuestras variables son significativamente diferentes.

# %% [markdown]
# Next, create a second regression model predicting value using potential. Create the model using `statsmodels` and print the model summary. Remember to add a constant term.

# %%
# Your code here:

x = sm.add_constant(fifa_new['Potential'])
y = fifa_new['ValueNumeric']

modelo = sm.OLS(y, x).fit()
print(modelo.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           ValueNumeric   R-squared:                       0.056
# Model:                            OLS   Adj. R-squared:                  0.056
# Method:                 Least Squares   F-statistic:                     1054.
# Date:                Thu, 30 Sep 2021   Prob (F-statistic):          9.15e-225
# Time:                        12:16:27   Log-Likelihood:            -1.2651e+05
# No. Observations:               17918   AIC:                         2.530e+05
# Df Residuals:                   17916   BIC:                         2.530e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1062.4312     24.547     43.281      0.000    1014.316    1110.546
# ...

# %% [markdown]
# Report your findings from the model summary. In particular, report about the model as a whole using the F-test and how much variation is predicted by the model using the r squared.

# %%
# Your conclusions here:

# Segun el modelo podemos concluir que la solo un 6% de la variacion de los datos del precio se pueden explicar con el 
# potencial del jugador. El r2 obtenido es muy bajo y debemos usar una mayor cantidad de variables para poder explicar
# mejor el comportamiento del precio.

# Por otro lado, nuesto p-value es menor a 0.05, por lo que rechazamos la hipotesis nula, lo que nos dice que la media
# de nuestras variables son significativamente diferentes.

# %% [markdown]
# Plot a scatter plot of value vs. potential. Do you see a linear relationship?

# %%
# Your code here:

plt.scatter(fifa_new['Potential'], fifa_new['ValueNumeric'])
plt.xlabel('Potential')
plt.ylabel('Price');

# %%
# Podemos ver que la relacion entre los valores no es lineal. Se expresaria mejor de forma exponencial.

# %% [markdown]
# Si volvemos al challenge 1, nos podemos dar cuenta de que al tomar la suposicion de no multiplicar nuestros datos por miles y millones, nuestro analisis anteriores carecen de sentido, ya que podemos tener jugadores con caracteristicas bajas de sprint y con precios altos ya que no hicimos uns distincion entre M y K. Debido a lo ya mencionado, tenemos que nuestros modelo no tienen sentido, ya que el Potencial del jugador tiene que estar directamente relacionado al precio, mientras mejor sea mas vale y nuestro r2 fue muy bajo.

# %%
# Multiplicando por M y K
fifa['ValueNumeric'] = fifa['Value'].apply(lambda x: float(x[1:-1])*1000000 if x[-1] == 'M' else (float(x[1:-1])*1000 if x[-1] == 'K' else float(x[-1])))

# %%
fifa_new = fifa.dropna() # Eliminamos las filas con valores nulos

# %%
# Modelo del precio y potencial del jugador

x = sm.add_constant(fifa_new['Potential'])
y = fifa_new['ValueNumeric']

modelo = sm.OLS(y, x).fit()
print(modelo.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           ValueNumeric   R-squared:                       0.336
# Model:                            OLS   Adj. R-squared:                  0.336
# Method:                 Least Squares   F-statistic:                     9058.
# Date:                Thu, 30 Sep 2021   Prob (F-statistic):               0.00
# Time:                        12:12:23   Log-Likelihood:            -3.0027e+05
# No. Observations:               17918   AIC:                         6.006e+05
# Df Residuals:                   17916   BIC:                         6.006e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -3.544e+07      4e+05    -88.693      0.000   -3.62e+07   -3.47e+07
# ...

# %% [markdown]
# Vemos como tenemos un mejor r2 usando el potencial del jugador

# %%
fig = px.scatter_3d(fifa_new, x='SprintSpeed', y='Stamina', z='ValueNumeric')
fig.show()
# Out:
# <div>                            <div id="379ddbc1-d326-423d-854d-a580d398fa54" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("379ddbc1-d326-423d-854d-a580d398fa54")) {                    Plotly.newPlot(                        "379ddbc1-d326-423d-854d-a580d398fa54",                        [{"hovertemplate":"SprintSpeed=%{x}<br>Stamina=%{y}<br>ValueNumeric=%{z}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"type":"scatter3d","x":[86.0,91.0,90.0,58.0,76.0,88.0,72.0,75.0,75.0,60.0,78.0,62.0,68.0,64.0,78.0,83.0,72.0,85.0,50.0,52.0,52.0,76.0,60.0,80.0,75.0,96.0,91.0,65.0,67.0,86.0,69.0,73.0,75.0,95.0,64.0,82.0,95.0,62.0,73.0,72.0,55.0,43.0,73.0,78.0,75.0,79.0
# ...

# %%
plt.scatter(fifa_new['Potential'], fifa_new['ValueNumeric'])
plt.xlabel('Potential')
plt.ylabel('Price');
